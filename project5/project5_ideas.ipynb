# %% [markdown]
# ## Project 5 - Ideas

# %%
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## H1B

# %%
def get_data(years):
    
    location = '/Users/laurengilson/Desktop/project5/data/H-1B_Disclosure_Data_FY{}.xlsx'
    dfs = []
        
    for year in years:
        
        print(f"{year} in progress...")
        read_data = pd.read_excel(location.format(year))
        read_data.columns = read_data.columns.str.replace(' ', '_')
        print(len(read_data))
        dfs.append(read_data)
        print(len(dfs))
        print(f"{year}: Done")
    
    return pd.concat(dfs, axis=0)

years = [2014, 2015, 2016, 2017, 2018, 2019]

# %%
visa_df = get_data(years)
# Out:
# 2014 in progress...
# 519504
# 1
# 2014: Done
# 2015 in progress...
# 618804
# 2
# 2015: Done
# 2016 in progress...
# 647852
# 3
# 2016: Done
# 2017 in progress...
# 624650
# 4
# 2017: Done
# 2018 in progress...
# 654360
# 5
# 2018: Done
# 2019 in progress...
# 97572
# 6
# 2019: Done

# %%
h1b = pd.DataFrame(h1b_visa)

# %%
h1b.tail()
# Out:
#           CASE_NUMBER DECISION_DATE CASE_STATUS CASE_RECEIVED_DATE REFILE  \
# 119771  A-18272-23782    2018-09-29   Withdrawn         2018-09-29      N
# 119772  A-18272-23783    2018-09-29   Withdrawn         2018-09-29      N
# 119773  A-18272-23780    2018-09-29   Withdrawn         2018-09-29      N
# 119774  A-18190-95289    2018-09-29   Withdrawn         2018-07-10      N
# 119775  A-18226-07714    2018-09-30   Withdrawn         2018-08-14      N
#
#        ORIG_FILE_DATE ORIG_CASE_NO SCHD_A_SHEEPHERDER  \
# 119771            NaT          NaN                  N
# 119772            NaT          NaN                  N
# 119773            NaT          NaN                  N
# 119774            NaT          NaN                  N
# 119775            NaT          NaN                  N
#
#                                             EMPLOYER_NAME  \
# 119771  TCB Quality Landscaping, Inc. dba TCB Landscaping
# 119772  TCB Quality Landscaping, Inc. dba TCB Landscaping
# ...

# %%
list(h1b.columns.values)
# Out:
# ['CASE_NUMBER',
#  'DECISION_DATE',
#  'CASE_STATUS',
#  'CASE_RECEIVED_DATE',
#  'REFILE',
#  'ORIG_FILE_DATE',
#  'ORIG_CASE_NO',
#  'SCHD_A_SHEEPHERDER',
#  'EMPLOYER_NAME',
#  'EMPLOYER_ADDRESS_1',
#  'EMPLOYER_ADDRESS_2',
#  'EMPLOYER_CITY',
#  'EMPLOYER_STATE',
#  'EMPLOYER_COUNTRY',
#  'EMPLOYER_POSTAL_CODE',
#  'EMPLOYER_PHONE',
#  'EMPLOYER_PHONE_EXT',
#  'EMPLOYER_NUM_EMPLOYEES',
#  'EMPLOYER_YR_ESTAB',
#  'FW_OWNERSHIP_INTEREST',
#  'AGENT_FIRM_NAME',
#  'AGENT_CITY',
#  'AGENT_STATE',
#  'PW_TRACK_NUM',
#  'PW_SOC_CODE',
#  'PW_SOC_TITLE',
#  'PW_LEVEL_9089',
#  'PW_AMOUNT_9089',
#  'PW_UNIT_OF_PAY_9089',
#  'PW_SOURCE_NAME_9089',
#  'PW_SOURCE_NAME_OTHER_9089',
#  'PW_DETERM_DATE',
#  'PW_EXPIRE_DATE',
#  'WAGE_OFFER_FROM_9089',
#  'WAGE_OFFER_TO_9089',
#  'WAGE_OFFER_UNIT_OF_PAY_9089',
#  'JOB_INFO_WORK_CITY',
#  'JOB_INFO_WORK_STATE',
#  'JOB_INFO_WORK_POSTAL_CODE',
#  'JOB_INFO_JOB_TITLE',
#  'JOB_INFO_EDUCATION',
#  'JOB_INFO_EDUCATION_OTHER',
#  'JOB_INFO_MAJOR',
# ...

# %%
h1b_visa2 = pd.read_excel('/Users/laurengilson/Desktop/project5/H-1B_Disclosure_Data_FY2018_Q4_EOY.xlsx')

# %%
h1b_visa2.head()
# Out:
#           CASE_NUMBER CASE_STATUS CASE_SUBMITTED DECISION_DATE VISA_CLASS  \
# 0  I-200-18026-338377   CERTIFIED     2018-01-29    2018-02-02       H-1B
# 1  I-200-17296-353451   CERTIFIED     2017-10-23    2017-10-27       H-1B
# 2  I-200-18242-524477   CERTIFIED     2018-08-30    2018-09-06       H-1B
# 3  I-200-18070-575236   CERTIFIED            NaT    2018-03-30       H-1B
# 4  I-200-18243-850522   CERTIFIED     2018-08-31    2018-09-07       H-1B
#
#   EMPLOYMENT_START_DATE EMPLOYMENT_END_DATE                EMPLOYER_NAME  \
# 0            2018-07-28          2021-07-27        MICROSOFT CORPORATION
# 1            2017-11-06          2020-11-06       ERNST & YOUNG U.S. LLP
# 2            2018-09-10          2021-09-09                 LOGIXHUB LLC
# 3            2018-09-10          2021-09-09  HEXAWARE TECHNOLOGIES, INC.
# 4            2018-09-07          2021-09-06             ECLOUD LABS,INC.
#
#   EMPLOYER_BUSINESS_DBA       EMPLOYER_ADDRESS  ... H1B_DEPENDENT  \
# ...

# %%
list(h1b_visa2.columns.values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-102-42046ccb7034> in <module>
# ----> 1 list(h1b_visa2.columns.values)
#
# NameError: name 'h1b_visa2' is not defined

# %%
# loop through dataframe and get unique values for each 
a = visa_df['AGENT_REPRESENTING_EMPLOYER'].unique()

# %%
col_name = []
unique_vals = []
headings = list(visa_df.columns.values)
for item in headings:
    col_name.append(item)
    unique_vals.append(visa_df[item].unique())

# %%
unique_dict = dict(zip(col_name, unique_vals))

# %%
unique_dict
# Out:
# {'AGENT_ATTORNEY_CITY': array([nan, 'MINNEAPOLIS', 'DALLAS', ..., 'BRIGHTON', 'PRATTVILLE',
#         'BRIDGETON'], dtype=object),
#  'AGENT_ATTORNEY_NAME': array([nan, 'DEBRA SCHNEIDER', 'HASEENA ENU', ..., 'ESPIONZA, ERICK',
#         'QUICHIZ, CARLOS', 'SMITH, J ANTHONY'], dtype=object),
#  'AGENT_ATTORNEY_STATE': array([nan, 'MN', 'TX', 'IL', 'DC', 'GA', 'CA', 'MI', 'NY', 'MA', 'WI',
#         'NC', 'PA', 'NJ', 'VA', 'CO', 'MD', 'OR', 'AZ', 'WA', 'IA', 'NE',
#         'FL', 'NH', 'IN', 'NM', 'OH', 'LA', 'CT', 'SC', 'MO', 'TN', 'KY',
#         'AL', 'ME', 'KS', 'OK', 'HI', 'MP', 'RI', 'ID', 'MT', 'DE', 'MS',
#         'AR', 'VT', 'UT', 'WV', 'ND', 'SD', 'GU', 'PR', 'NV', 'AK', 'WY',
#         'VI', 'AS'], dtype=object),
#  'AGENT_REPRESENTING_EMPLOYER': array([nan, 'Y', 'N'], dtype=object),
#  'AMENDED_PETITION': array([ nan,   0.,   1.,  15.,  11.,   4.,  10.,   5.,   2.,   3.,   9.,
#           8.,   7.,  25.,   6.,  30.,  20.,  50.,  34.,  18.,  13.,  45.,
# ...

# %%
visa_df.head()
# Out:
#   AGENT_ATTORNEY_CITY AGENT_ATTORNEY_NAME AGENT_ATTORNEY_STATE  \
# 0                 NaN                 NaN                  NaN
# 1                 NaN                 NaN                  NaN
# 2                 NaN                 NaN                  NaN
# 3                 NaN                 NaN                  NaN
# 4                 NaN                 NaN                  NaN
#
#   AGENT_REPRESENTING_EMPLOYER  AMENDED_PETITION CASE_NUMBER CASE_STATUS  \
# 0                         NaN               NaN         NaN         NaN
# 1                         NaN               NaN         NaN         NaN
# 2                         NaN               NaN         NaN         NaN
# 3                         NaN               NaN         NaN         NaN
# 4                         NaN               NaN         NaN         NaN
#
#   CASE_SUBMITTED  CHANGE_EMPLOYER  CHANGE_PREVIOUS_EMPLOYMENT  ...  \
# 0            NaT              NaN                         NaN  ...
# ...

# %%
list(visa_df.columns.values)
# Out:
# ['AGENT_ATTORNEY_CITY',
#  'AGENT_ATTORNEY_NAME',
#  'AGENT_ATTORNEY_STATE',
#  'AGENT_REPRESENTING_EMPLOYER',
#  'AMENDED_PETITION',
#  'CASE_NUMBER',
#  'CASE_STATUS',
#  'CASE_SUBMITTED',
#  'CHANGE_EMPLOYER',
#  'CHANGE_PREVIOUS_EMPLOYMENT',
#  'CONTINUED_EMPLOYMENT',
#  'DECISION_DATE',
#  'EMPLOYER_ADDRESS',
#  'EMPLOYER_ADDRESS1',
#  'EMPLOYER_ADDRESS2',
#  'EMPLOYER_BUSINESS_DBA',
#  'EMPLOYER_CITY',
#  'EMPLOYER_COUNTRY',
#  'EMPLOYER_NAME',
#  'EMPLOYER_PHONE',
#  'EMPLOYER_PHONE_EXT',
#  'EMPLOYER_POSTAL_CODE',
#  'EMPLOYER_PROVINCE',
#  'EMPLOYER_STATE',
#  'EMPLOYMENT_END_DATE',
#  'EMPLOYMENT_START_DATE',
#  'FULL_TIME_POS',
#  'FULL_TIME_POSITION',
#  'H-1B_DEPENDENT',
#  'H1B_DEPENDENT',
#  'JOB_TITLE',
#  'LABOR_CON_AGREE',
#  'LCA_CASE_EMPLOYER_ADDRESS',
#  'LCA_CASE_EMPLOYER_CITY',
#  'LCA_CASE_EMPLOYER_NAME',
#  'LCA_CASE_EMPLOYER_POSTAL_CODE',
#  'LCA_CASE_EMPLOYER_STATE',
#  'LCA_CASE_EMPLOYMENT_END_DATE',
#  'LCA_CASE_EMPLOYMENT_START_DATE',
# ...

# %%
visa_df.dropna()
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# ## Perm Res

# %% [markdown]
# ### Import data

# %%
def GetPermData(years):
    
    location = '/Users/laurengilson/Desktop/perm_data/PERM_FY{}.xlsx'
    dfs = []
        
    for year in years:
        print(f"{year} in progress...")
        # Read in excel for particular year
        read_data = pd.read_excel(location.format(year))
        
        # set column headers to lower case and remove spaces
        read_data.columns = list(map(lambda header : header.lower(), read_data.columns)) # make all lowercase
        read_data.colums = read_data.columns.str.replace(' ','_') # replace spaces with underscores

        # add column of fiscal year to df
        read_data['fiscal_year'] = str(year) 
        dfs.append(read_data) # append to list
        print(len(dfs))
        print(f"{year}: Done")
    
    return pd.concat(dfs, axis=0, ignore_index=True)

years = [2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]

# %%
test_df = GetPermData([2019])
# Out:
# 2019 in progress...
# 1
# 2019: Done

# %%
test_df
# Out:
#          case_number decision_date case_status case_received_date refile  \
# 0      A-18207-01638     10/1/2018   Withdrawn         2018-10-01      N
# 1      A-18274-24108     10/1/2018   Withdrawn         2018-10-01      N
# 2      A-18274-23991     10/1/2018   Withdrawn         2018-10-01      N
# 3      A-18274-24040     10/1/2018   Withdrawn         2018-10-01      N
# 4      A-18269-22483     10/1/2018   Withdrawn         2018-09-28      N
# 5      A-18266-21196     10/1/2018   Withdrawn         2018-09-27      N
# 6      A-18207-01605     10/1/2018   Withdrawn         2018-09-27      N
# 7      A-18212-03230     10/1/2018   Withdrawn         2018-09-24      N
# 8      A-18235-10635     10/1/2018   Withdrawn         2018-09-21      N
# 9      A-18263-20630     10/1/2018   Withdrawn         2018-09-20      N
# 10     A-18242-13010     10/1/2018      Denied         2018-08-29      N
# 11     A-18233-09787     10/1/2018   Certified         2018-08-27      Y
# ...

# %%
perm_df = get_perm_data(2008)
# Out:
# 2008 in progress...
# 61997
# 1
# 2008: Done
# 2009 in progress...
# 38247
# 2
# 2009: Done
# 2010 in progress...
# 81412
# 3
# 2010: Done
# 2011 in progress...
# 73207
# 4
# 2011: Done
# 2012 in progress...
# 66488
# 5
# 2012: Done
# 2013 in progress...
# 44152
# 6
# 2013: Done
# 2014 in progress...
# 70998
# 7
# 2014: Done
# 2015 in progress...
# 89299
# 8
# 2015: Done
# 2016 in progress...
# 126143
# 9
# 2016: Done
# 2017 in progress...
# 97603
# 10
# 2017: Done
# 2018 in progress...
# 119776
# 11
# 2018: Done
# 2019 in progress...
# 17881
# 12
# 2019: Done

# %%
list(perm_df.columns.values)
# Out:
# ['2007_naics_us_code',
#  '2007_naics_us_title',
#  'add_these_pw_job_title_9089',
#  'agent_city',
#  'agent_firm_name',
#  'agent_state',
#  'application_type',
#  'case_no',
#  'case_number',
#  'case_received_date',
#  'case_status',
#  'class_of_admission',
#  'country_of_citizenship',
#  'country_of_citzenship',
#  'decision_date',
#  'employer_address_1',
#  'employer_address_2',
#  'employer_city',
#  'employer_country',
#  'employer_decl_info_title',
#  'employer_name',
#  'employer_num_employees',
#  'employer_phone',
#  'employer_phone_ext',
#  'employer_postal_code',
#  'employer_state',
#  'employer_yr_estab',
#  'fiscal_year',
#  'foreign_worker_info_city',
#  'foreign_worker_info_education',
#  'foreign_worker_info_inst',
#  'foreign_worker_info_major',
#  'foreign_worker_info_state',
#  'fw_info_alt_edu_experience',
#  'fw_info_birth_country',
#  'fw_info_education_other',
#  'fw_info_postal_code',
#  'fw_info_rel_occup_exp',
#  'fw_info_rel_occup_experience',
# ...

# %%
# pickle original imported df
import pickle
perm_df.to_pickle("./perm_df.pkl")

# %%
# Unpickle
perm_df = pd.read_pickle("./perm_df.pkl")

# %%
# Make deepcopy of dataframe
import copy 
perm_to_edit = copy.deepcopy(perm_df)

# %% [markdown]
# ### Merge columns that are the same with different headers

# %%
# or use this to fill NaN values of one column with another
# Case Number
perm_to_edit['case_number'].fillna(perm_to_edit['case_no'], inplace=True)

# %%
# Country of citizenship
perm_to_edit['country_of_citizenship'].fillna(perm_to_edit['country_of_citzenship'], inplace=True)

# %%
# Rel_occup_experience
perm_to_edit['fw_info_rel_occup_experience'].fillna(perm_to_edit['fw_info_rel_occup_exp'], inplace=True)

# %%
# Domestic service
perm_to_edit['ji_live_in_dom_svc_contract'].fillna(perm_to_edit['ji_live_in_domestic_service'], inplace=True)

# %%
# Offer to sec jfw
perm_to_edit['ji_offered_to_sec_j_foreign_worker'].fillna(perm_to_edit['ji_offered_to_sec_j_fw'], inplace=True)

# %% [markdown]
# ### Check country of citizenship & place of birth

# %%
# check unique values of country of citizenship
list(perm_to_edit['country_of_citizenship'].unique())
# Out:
# ['MAURITANIA',
#  'PAKISTAN',
#  'PHILIPPINES',
#  'PORTUGAL',
#  'SIERRA LEONE',
#  'HUNGARY',
#  'COLOMBIA',
#  'SOUTH AFRICA',
#  'PERU',
#  'ECUADOR',
#  'GUATEMALA',
#  'BOLIVIA',
#  nan,
#  'JAMAICA',
#  'MEXICO',
#  'NIGERIA',
#  'TRINIDAD AND TOBAGO',
#  'POLAND',
#  'GUYANA',
#  'CHINA',
#  'INDIA',
#  'ITALY',
#  'BRAZIL',
#  'UNITED KINGDOM',
#  'GRENADA',
#  'THAILAND',
#  'SYRIA',
#  'MONGOLIA',
#  'BANGLADESH',
#  'ARGENTINA',
#  'SOUTH KOREA',
#  'GREECE',
#  'BAHAMAS',
#  'DOMINICAN REPUBLIC',
#  'COSTA RICA',
#  'TURKEY',
#  'ISRAEL',
#  'SLOVAKIA',
#  'NEPAL',
#  'EGYPT',
#  'GERMANY',
#  'EL SALVADOR',
#  'CANADA',
#  'SURINAME',
#  'TUNISIA',
#  'JORDAN',
#  'SRI LANKA',
#  'NORWAY',
#  'FRANCE',
#  'UNITED STATES OF AMERICA',
#  'GHANA',
#  'INDONESIA',
#  'BENIN',
#  'TAIWAN',
#  'JAPAN',
#  'IRAN',
#  'KENYA',
#  'SWITZERLAND',
#  'ALBANIA',
#  'SPAIN',
#  'NEW ZEALAND',
#  'HONG KONG',
#  'AUSTRALIA',
#  'IRAQ',
#  'ROMANIA',
#  'PANAMA',
# ...

# %%
# same for 'fw_info_birth_country'
list(perm_to_edit['fw_info_birth_country'].unique())
# Out:
# [nan,
#  'INDIA',
#  'SOUTH KOREA',
#  'BANGLADESH',
#  'PHILIPPINES',
#  'CHINA',
#  'UNITED KINGDOM',
#  'JORDAN',
#  'SAUDI ARABIA',
#  'NIGERIA',
#  'ISRAEL',
#  'COLOMBIA',
#  'RUSSIA',
#  'SPAIN',
#  'PARAGUAY',
#  'NEPAL',
#  'ITALY',
#  'CANADA',
#  'SRI LANKA',
#  'PAKISTAN',
#  'FRANCE',
#  'GHANA',
#  'EL SALVADOR',
#  'IRAN',
#  'NETHERLANDS',
#  'POLAND',
#  'TURKEY',
#  'SENEGAL',
#  'MEXICO',
#  'LEBANON',
#  'MALAYSIA',
#  'NICARAGUA',
#  'ECUADOR',
#  'ROMANIA',
#  'CZECH REPUBLIC',
#  'HONG KONG',
#  'SOUTH AFRICA',
#  'PERU',
#  'BRAZIL',
#  'BELGIUM',
#  'VENEZUELA',
#  'VIETNAM',
#  'JAPAN',
#  'GERMANY',
#  'HUNGARY',
#  'INDONESIA',
#  'HONDURAS',
#  'GUATEMALA',
#  'TAIWAN',
#  'UKRAINE',
#  'KENYA',
#  'ARGENTINA',
#  'URUGUAY',
#  'HAITI',
#  'FINLAND',
#  'DOMINICAN REPUBLIC',
#  'SINGAPORE',
#  'IRELAND',
#  'GUYANA',
#  'ETHIOPIA',
#  'AUSTRALIA',
#  'DENMARK',
#  'AUSTRIA',
#  'UNITED ARAB EMIRATES',
#  'JAMAICA',
#  'PORTUGAL',
#  'GREECE',
# ...

# %%
def ColValueCheck(col_1, col_2):
    
    '''Creates a new column from values of two other columns 
    dependent on whether columns have the same value
    
    Inputs: 2 columns from dataframe
    
    Assumptions: Assumes if there is a NaN value, it would be the same
    as the other column value'''
    
    col_1 = col_1.fillna('None')
    col_2 = col_2.fillna('None')
    
    new_col = []
    
    for idx, value in enumerate(col_1):
        if col_1[idx] == 'None' or col_2[idx] == 'None':
            new_col.append(1)
        elif col_1[idx] == col_2[idx]:
            new_col.append(1)
        else:
            new_col.append(0)
    
    return new_col

# %%
# Create citizenship same as birth country column
citizenship_same_as_birth = list(ColValueCheck(perm_to_edit['country_of_citizenship'], perm_to_edit['fw_info_birth_country']))
perm_to_edit['citizenship_same_as_birth'] = citizenship_same_as_birth

# %%
list(perm_to_edit['citizenship_same_as_birth'].unique())
# Out:
# [1, 0]

# %% [markdown]
# ### Clean and check worker state & employer state

# %%
for tuples in list(zip(perm_to_edit['foreign_worker_info_state'], perm_to_edit['employer_state'])):
    if np.nan not in tuples:
        print(tuples)

# %%
us_state_abbrev = {
    'alabama': 'AL',
    'alaska': 'AK',
    'american samoa' : 'AS',
    'arizona': 'AZ',
    'arkansas': 'AR',
    'british columbia' : 'BC',
    'california': 'CA',
    'colorado': 'CO',
    'connecticut': 'CT',
    'delaware': 'DE',
    'district of columbia' : 'DC',
    'florida': 'FL',
    'georgia': 'GA',
    'guam' : 'GU',
    'hawaii': 'HI',
    'idaho': 'ID',
    'illinois': 'IL',
    'indiana': 'IN',
    'iowa': 'IA',
    'kansas': 'KS',
    'kentucky': 'KY',
    'louisiana': 'LA',
    'maine': 'ME',
    'marshall islands' : 'MH',
    'maryland': 'MD',
    'massachusetts': 'MA',
    'michigan': 'MI',
    'minnesota': 'MN',
    'mississippi': 'MS',
    'missouri': 'MO',
    'montana': 'MT',
    'nebraska': 'NE',
    'nevada': 'NV',
    'new hampshire': 'NH',
    'new jersey': 'NJ',
    'new mexico': 'NM',
    'new york': 'NY',
    'north carolina': 'NC',
    'north dakota': 'ND',
    'northern mariana islands' : 'MP',
    'ohio': 'OH',
    'oklahoma': 'OK',
    'oregon': 'OR',
    'pennsylvania': 'PA',
    'puerto rico' : 'PR',
    'rhode island': 'RI',
    'south carolina': 'SC',
    'south dakota': 'SD',
    'tennessee': 'TN',
    'texas': 'TX',
    'utah': 'UT',
    'vermont': 'VT',
    'virginia': 'VA',
    'virgin islands' : 'VI',
    'washington': 'WA',
    'west virginia': 'WV',
    'wisconsin': 'WI',
    'wyoming': 'WY',
}

# %%
def StateAbbreviation(state_col):
    
    '''Abbreviates any full length state names into their corresponding
    two letter code'''
    
    state_col = state_col.fillna(str('none'))
    state_col = list(map(str, state_col))
    state_col = list(map(lambda state:state.lower(), state_col))

    abbrev_list = []
    
    for item in state_col:
        
        if item in us_state_abbrev:
            abbrev_list.append(us_state_abbrev[item].upper())
        else:
            abbrev_list.append(item.upper())

    return abbrev_list

# %%
len(perm_to_edit['foreign_worker_info_state'])
# Out:
# 887203

# %%
# Abbreviate - foreign worker state - state of foreign worker
perm_to_edit['fw_worker_state_abv'] = StateAbbreviation(perm_to_edit['foreign_worker_info_state'])

# %%
perm_to_edit.tail()
# Out:
#        2007_naics_us_code 2007_naics_us_title add_these_pw_job_title_9089  \
# 887198                NaN                 NaN                         NaN
# 887199                NaN                 NaN                         NaN
# 887200                NaN                 NaN                         NaN
# 887201                NaN                 NaN                         NaN
# 887202                NaN                 NaN                         NaN
#
#           agent_city                    agent_firm_name agent_state  \
# 887198     San Diego       Higgs, Fletcher, & Mack, LLP          CA
# 887199  FARMINGVILLE                        LAW OFFICES          NY
# 887200        Frisco  Law Office of Eric A. Fisher, LLC          CO
# 887201           NaN                                NaN         NaN
# 887202   Los Angeles   Santa Clarita Legal Services Cor          CA
#
#        application_type case_no    case_number case_received_date  ...  \
# ...

# %%
# Abbreviate - employer state -
perm_to_edit['employer_state_abv'] = StateAbbreviation(perm_to_edit['employer_state'])

# %% [markdown]
# ### Check number of NaN values to choose columns

# %%
for column in list(perm_to_edit.columns):
    nan_num = len(perm_to_edit) - perm_to_edit[column].count()
    print(f"{column} : There are {nan_num} NaN values out of {len(perm_to_edit)}")
# Out:
# 2007_naics_us_code : There are 453797 NaN values out of 887203
# 2007_naics_us_title : There are 527212 NaN values out of 887203
# add_these_pw_job_title_9089 : There are 844839 NaN values out of 887203
# agent_city : There are 481374 NaN values out of 887203
# agent_firm_name : There are 490294 NaN values out of 887203
# agent_state : There are 490388 NaN values out of 887203
# application_type : There are 450702 NaN values out of 887203
# case_no : There are 550946 NaN values out of 887203
# case_number : There are 0 NaN values out of 887203
# case_received_date : There are 436503 NaN values out of 887203
# case_status : There are 0 NaN values out of 887203
# class_of_admission : There are 68903 NaN values out of 887203
# country_of_citizenship : There are 178 NaN values out of 887203
# country_of_citzenship : There are 565940 NaN values out of 887203
# decision_date : There are 0 NaN values out of 887203
# employer_address_1 : There are 80 NaN values out of 887203
# ...

# %%
perm_to_edit.head()
# Out:
#   2007_naics_us_code 2007_naics_us_title add_these_pw_job_title_9089  \
# 0                NaN        UNCLASSIFIED                         NaN
# 1                NaN        UNCLASSIFIED                         NaN
# 2                NaN        UNCLASSIFIED                         NaN
# 3                NaN        UNCLASSIFIED                         NaN
# 4                NaN        UNCLASSIFIED                         NaN
#
#   agent_city agent_firm_name agent_state application_type case_no  \
# 0        NaN             NaN         NaN             PERM     NaN
# 1        NaN             NaN         NaN             PERM     NaN
# 2        NaN             NaN         NaN             PERM     NaN
# 3        NaN             NaN         NaN             PERM     NaN
# 4        NaN             NaN         NaN             PERM     NaN
#
#      case_number case_received_date  ... ri_us_workers_considered  \
# 0  A-08271-91262                NaT  ...                      NaN
# ...

# %% [markdown]
# ### Check out education columns - maybe combine

# %%
perm_to_edit['fw_info_education_other']
# Out:
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# 5                                                      NaN
# 6                                                      NaN
# 7                                                      NaN
# 8                                                      NaN
# 9                                                      NaN
# 10                                                     NaN
# 11                                                     NaN
# 12                                                     NaN
# 13                                                     NaN
# 14                                                     NaN
# 15                                                     NaN
# ...
